# %% [markdown]
# # Model Validation --- Negative Bionomial for Rate modeling
# ## Based on the simulated residuals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Random effect validation using catplot mean centered around 0 the mean is in log scaled

# %% [markdown]
# ![image.png](attachment:image.png)
