# %% [markdown]
# # Model validation
# ## QQ plot residuals, since this is odds ratio model,  it is from simulated distribution using DHRUM packages

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Validation of the Outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Validation of dispersion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Test for zero inflation

# %% [markdown]
# ![image.png](attachment:image.png)
